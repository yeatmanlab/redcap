# %%
import pandas as pd
import numpy as np

# %%
all_adu = pd.read_csv('~/Downloads/RDRPRepository_DATA_2017-03-23_1434.csv', index_col='record_id')
ctopps = pd.read_csv('~/Downloads/RDRPRepository_DATA_2017-03-23_1407.csv', index_col='record_id')

# %%
all_set = set(all_adu.index)
ctopp_set = set(pd.unique(ctopps.index))
need_ctopp = all_set.difference(ctopp_set)
len(all_set)
len(ctopp_set)
#len(need_ctopp)
# Out:
# 19

# %%
all_adu.loc[need_ctopp]
# Out:
#               redcap_event_name    sid  dys_dx  nlr_id
# record_id
# 257        subject_intake_arm_1  SB257       1  511_RC
# 258        subject_intake_arm_1  OB258       0     NaN
# 259        subject_intake_arm_1  OB259       0     NaN
# 260        subject_intake_arm_1  OB260       0  508_RC
# 262        subject_intake_arm_1  PB262       1     NaN
# 272        subject_intake_arm_1  RB272       0     NaN
# 286        subject_intake_arm_1  RB286       1     NaN
# 295        subject_intake_arm_1  SB295       0     NaN
# 297        subject_intake_arm_1  QB297       0     NaN
# 305        subject_intake_arm_1  PB305       1     NaN
# 223        subject_intake_arm_1  PB223       0     NaN
# 212        subject_intake_arm_1  OB212       0     NaN
# 216        subject_intake_arm_1  QB216       0     NaN
# 90         subject_intake_arm_1  OA090     NaN  501_SS
# 91         subject_intake_arm_1  OA091     NaN  502_HW
# 92         subject_intake_arm_1  QA092     NaN  503_AH
# ...

# %%
for sub in pd.unique(ctopps.index):
    all_adu.pop(sub)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-c25c03321058> in <module>()
#       1 for sub in pd.unique(ctopps.index):
# ----> 2     all_adu.pop(sub)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in pop(self, item)
#     503         Return item and drop from frame. Raise KeyError if not found.
#     504         """
# --> 505         result = self[item]
#     506         del self[item]
#     507         try:
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# //anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
# ...
