# %%
import pandas as pd
import numpy as np

# %%
# load data
data = pd.read_csv('/Users/douglasstrodtman/Downloads/nlr.csv')

# select adult rows
adults = data[250:]

# build list of dyslexic adults
threshold = 85

# %%
dys = adults[adults.TWRE_INDEX <= threshold]
len(pd.unique(dys.Subject))
# Out:
# 14

# %%
dys = dys.combine_first(adults[adults.TWRE_SWE_SS <= threshold])
dys = dys.combine_first(adults[adults.TWRE_PDE_SS <= threshold])

dys_c = dys.combine_first(adults[adults.CTOPP_PM <= threshold])
dys_c = dys.combine_first(adults[adults.CTOPP_RAPID <= threshold])

# extract unique subs
subs = pd.unique(dys.Subject)


# exclude teens and elders
exclude = np.array(['401_JB', '402_RB', 'NB249', '601_CC', '602_JK'])

adu_dys = dys

for sub in exclude:
	adu_dys = adu_dys[adu_dys.Subject != sub]
	


# select only the columns that are pertinent to the current evaluations
final = adu_dys.ix[:, ['Subject', 'Visit', 'TWRE_SWE_SS', 'TWRE_PDE_SS', 'TWRE_INDEX', 'CTOPP_PM', 'CTOPP_RAPID']]

# %%
final
# Out:
#     Subject  Visit  TWRE_SWE_SS  TWRE_PDE_SS  TWRE_INDEX  CTOPP_PM  \
# 258  502_HW      1           79           64          71       NaN
# 259  502_HW      2           82           71          75       NaN
# 270  507_JP      1           98           85          91       NaN
# 271  507_JP      2          100           77          88       NaN
# 274  508_RC      1           82          109          95       NaN
# 279  510_DT      1           88           84          85       NaN
# 280  510_DT      2           91           85          87       NaN
# 283  511_RC      1           71           71          69       NaN
# 284  511_RC      2           65           67          64       NaN
# 288  513_EO      1           72           83          76       NaN
# 295  516_TT      1           71           89          79       NaN
# 297  516_TT      3           77           90          83       NaN
# 308  520_AA      1           89           80          84       NaN
# ...

# %%
good = 100
dys = adults[adults.TWRE_INDEX >= good]
dys = dys.combine_first(adults[adults.TWRE_SWE_SS >= good])
dys = dys.combine_first(adults[adults.TWRE_PDE_SS >= good])

dys_c = dys.combine_first(adults[adults.CTOPP_PM >= good])
dys_c = dys.combine_first(adults[adults.CTOPP_RAPID >= good])

# extract unique subs
subs = pd.unique(dys.Subject)
