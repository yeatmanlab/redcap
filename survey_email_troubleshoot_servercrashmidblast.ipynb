# %%
import pandas as pd

# %%
import os
import glob
import sys

# %%
home = os.path.expanduser('~')

# %%
repo_file = max(glob.iglob(home+'/Downloads/RDRPRepository_DATA_*'), key=os.path.getctime)

# %%
repo_data = pd.read_csv(repo_file, index_col='sid')

# %%
ss_data = pd.read_csv('/home/pdonnelly/Downloads/surveys_sent.csv', index_col='sid', dtype = object)

# %%
repo_data['survey_sent'] = ss_data.survey_sent

# %%
repo_data.set_index('record_id', inplace = True)

# %%
sum(repo_data.survey_sent=='1')
# Out:
# 104

# %%
repo_data.to_csv('/home/pdonnelly/Downloads/fixed_sent.csv')

# %%
repo_data
# Out:
#               redcap_event_name survey_sent
# record_id
# 1          subject_intake_arm_1         NaN
# 2          subject_intake_arm_1         NaN
# 3          subject_intake_arm_1         NaN
# 4          subject_intake_arm_1         NaN
# 5          subject_intake_arm_1           1
# 6          subject_intake_arm_1         NaN
# 7          subject_intake_arm_1         NaN
# 8          subject_intake_arm_1         NaN
# 9          subject_intake_arm_1         NaN
# 10         subject_intake_arm_1         NaN
# 11         subject_intake_arm_1         NaN
# 12         subject_intake_arm_1         NaN
# 13         subject_intake_arm_1         NaN
# 14         subject_intake_arm_1         NaN
# 15         subject_intake_arm_1         NaN
# 16         subject_intake_arm_1         NaN
# 17         subject_intake_arm_1         NaN
# 18         subject_intake_arm_1         NaN
# 19         subject_intake_arm_1         NaN
# 20         subject_intake_arm_1         NaN
# ...
